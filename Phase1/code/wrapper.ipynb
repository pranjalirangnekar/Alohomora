# %%
import numpy as np
from scipy.ndimage import rotate
from scipy.signal import convolve2d
from scipy.ndimage import convolve
from sklearn.cluster import KMeans
import importlib
import cv2
import os
import matplotlib.pyplot as plt
import LM
import DoG
import Gabor
import half_disk
import texton
import Brightness
import Color

image_save_path = '/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500'

# %%
importlib.reload(DoG)
scales = [1, 2]  # Two scales
orientations = 16  # Sixteen orientations
size = 15
save_path = image_save_path + '/DoG.png'
DoG_Filter_Bank = DoG.oriented_dog_filters(scales, orientations, size, save_path, display=False)
print(np.shape(DoG_Filter_Bank))
# Out:
# (32, 15, 15)

# %%
importlib.reload(LM)    
filt_type = "LML"
filters = LM.makeLMfilters(filt_type) # or "LML"
LM.visualize_filters(filters, image_save_path + f'/{filt_type}.png', display=True)

# %%
size = 64
num_filters = 40
wavelengths = [10, 15, 20]
orientations = np.linspace(0, np.pi, 8)
sigmas = [10, 15]
aspect_ratios = [0.5, 1.0]
phases = [0, np.pi/2]

gabor_filters = Gabor.generate_gabor_filters(num_filters, size, wavelengths, orientations, sigmas, aspect_ratios, phases)
Gabor.visualize_filters(gabor_filters, image_save_path + '/Gabor.png', display=False)

# %%
radius = [4, 10, 20]
importlib.reload(half_disk)
orientations = np.linspace(0, 360, 16, endpoint=False)
orientations = [0.0, 180, 22.5, 202.5, 45, 225, 67.5, 247.5, 90, 270, 112.5, 292.5, 135.0, 315, 157.5, 337.5]
half_disk_masks = half_disk.generate_half_disk_masks(radius, orientations)
half_disk.visualize_filters(half_disk_masks, image_save_path + '/HDMasks.png', display=False)

# %%
importlib.reload(texton)
image_folder = '/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Images'
image_paths = [image_folder + os.path.sep + f'{f}.jpg' for f in range(1, 11)]
filter_bank = DoG_Filter_Bank ## Use the filter bank as needed
texton_maps = texton.generate_texton_map(image_paths, filter_bank)

# %%
importlib.reload(texton)
save_image_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Texton_Maps"
texture_ids = texton.generate_texture_ids(image_paths, texton_maps, 128, save_image_path)
# Out:
# Processing image 1/10
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Processing image 2/10
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Processing image 3/10
# /opt/homebrew/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:1416: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)
# Processing image 4/10
# ...

# %%
importlib.reload(texton)
image_save_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Texton_Gradient"
masks = half_disk_masks
texton_gradients = texton.generate_texton_gradient(image_paths, texton_maps, 128, masks, image_save_path)
# Out:
# Processing image 1/10
# Processing image 2/10
# Processing image 3/10
# Processing image 4/10
# Processing image 5/10
# Processing image 6/10
# Processing image 7/10
# Processing image 8/10
# Processing image 9/10
# Processing image 10/10

# %%
print(np.shape(texton_gradients[0]))
# Out:
# (321, 481, 3)

# %%
importlib.reload(Brightness)
image_save_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Brightness_Maps"
brightness_maps = Brightness.generate_brightness_map(image_paths, 16, image_save_path)
# Out:
# Processing image 1/10
# Processing image 2/10
# Processing image 3/10
# Processing image 4/10
# Processing image 5/10
# Processing image 6/10
# Processing image 7/10
# Processing image 8/10
# Processing image 9/10
# Processing image 10/10

# %%
importlib.reload(Brightness)
image_save_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Brightness_Gradient"
masks = half_disk_masks
brightness_gradients = Brightness.generate_brightness_gradient_with_masks(image_paths, brightness_maps, 16, masks, image_save_path)
# Out:
# Processing image 1/10
# Processing image 2/10
# Processing image 3/10
# Processing image 4/10
# Processing image 5/10
# Processing image 6/10
# Processing image 7/10
# Processing image 8/10
# Processing image 9/10
# Processing image 10/10

# %%
importlib.reload(Color)
image_save_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Color_Maps"
# color_maps = Color.generate_color_map(image_paths, 16, 'RGB', image_save_path)
# color_maps = Color.generate_color_map(image_paths, 16, 'YCbCr', image_save_path)
# color_maps = Color.generate_color_map(image_paths, 16, 'HSV', image_save_path)
color_maps = Color.generate_color_map(image_paths, 16, 'Lab', image_save_path)
# Out:
# Processing image 1/10
# Processing image 2/10
# Processing image 3/10
# Processing image 4/10
# Processing image 5/10
# Processing image 6/10
# Processing image 7/10
# Processing image 8/10
# Processing image 9/10
# Processing image 10/10

# %%
importlib.reload(Color)
masks = half_disk_masks
image_save_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Color_Gradient"
color_gradients = Color.generate_color_gradient_with_masks(image_paths, color_maps, 16, masks, image_save_path)
# Out:
# Processing image 1/10
# Processing image 2/10
# Processing image 3/10
# Processing image 4/10
# Processing image 5/10
# Processing image 6/10
# Processing image 7/10
# Processing image 8/10
# Processing image 9/10
# Processing image 10/10

# %%
sobel_images_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/SobelBaseline"
sobel_img = [sobel_images_path + os.path.sep + f'{f}.png' for f in range(1, 11)]
sobel_images = [None] * len(sobel_img)
for i in range(len(sobel_img)):
    sobel_images[i] = cv2.imread(sobel_img[i])

# %%
canny_images_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/SobelBaseline"
canny_img = [canny_images_path + os.path.sep + f'{f}.png' for f in range(1, 11)]
canny_images = [None] * len(canny_img)
for i in range(len(canny_img)):
    canny_images[i] = cv2.imread(canny_img[i])

# %%
Tg = texton_gradients
Bg = brightness_gradients
Cg = color_gradients
Sg = sobel_images
Cg = canny_images


for i in range(10):
    print(np.shape(Tg[i]), end = " ")
    print(np.shape(Bg[i]), end = " ")
    print(np.shape(Cg[i]), end = " ")
    print(np.shape(Sg[i]), end = " ")
    print(np.shape(Cg[i]))
# Out:
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (321, 481, 3) (321, 481) (321, 481, 3) (321, 481, 3) (321, 481, 3)
# (481, 321, 3) (481, 321) (481, 321, 3) (481, 321, 3) (481, 321, 3)

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.2989, 0.5870, 0.1140])


image_save_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/PbLite_Images"

for i in range(10):
    w1 = 0.5
    w2 = 0.5
    a = (rgb2gray(Tg[i]) * Bg[i] * rgb2gray(Cg[i]))
    b = w1 * rgb2gray(Sg[i]) + w2 * rgb2gray(Cg[i])

    PbEdges = a * b

    cv2.imwrite(image_save_path + os.path.sep + f'{i+1}.png', PbEdges)

# %%
# ## Visualization Images
# folder_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500"

# f1 = 'Texton_Maps'
# f2 = 'Texton_Gradient'
# f3 = 'Brightness_Maps'
# f4 = 'Brightness_gradient'
# f5 = 'Color_Maps'
# f6 = 'Color_Gradient'
# Tm = texton_maps
# Tg = texton_gradients
# Bm = brightness_maps
# Bg = brightness_gradients
# Cm = color_maps
# Cg = color_gradients

# for i in range(10):
#     print(np.shape(Tm[i]), end = " ")
#     print(np.shape(Tg[i]), end = " ")
#     print(np.shape(Bm[i]), end = " ")
#     print(np.shape(Bg[i]), end = " ")
#     print(np.shape(Cm[i]), end = " ")
#     print(np.shape(Cg[i]))
#     img1 = np.array(Tm[i])
#     img2 = np.array(Bm[i])
#     img3 = np.array(Cm[i])
#     print(img3)
#     # im_h = cv2.hconcat([img1, img2])
#     # im_h = cv2.hconcat([im_h, img3])
#     cv2.imshow("test", img3)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
#     break

# %%
folder_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500"
ls = os.listdir(folder_path)
ls = ['Brightness_Maps', 'PbLite_Images', 'Color_Gradient', 'Texton_Maps', 'Brightness_Gradient', 'Texton_Gradient', 'Color_Maps']
for i in ls:
    os.mkdir(f"{folder_path}/{i}")

# %%
folder_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500"
ls = ['Texton_Maps', 'Texton_Gradient', 'Brightness_Maps', 'Brightness_Gradient', 'Color_Maps', 'Color_Gradient', 'SobelBaseline', 'CannyBaseline', 'PbLite_Images']
save_folder_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/outputs"
import cv2
for i in range(10):
    Tm_img_path = f"{folder_path}/{ls[0]}/TextonMap_{i+1}.png"
    Bm_img_path = f"{folder_path}/{ls[2]}/BrightnessMap_{i+1}.png"
    Cm_img_path = f"{folder_path}/{ls[4]}/ColorMap_{i+1}.png"
    img1 = cv2.imread(Tm_img_path)
    img2 = cv2.imread(Bm_img_path)
    img3 = cv2.imread(Cm_img_path)
    img = cv2.hconcat([img1, img2, img3])
    filename = f"{save_folder_path}/map_{i+1}.png"
    cv2.imwrite(filename, img)

for i in range(10):
    Tm_img_path = f"{folder_path}/{ls[1]}/Tg_{i+1}.png"
    Bm_img_path = f"{folder_path}/{ls[3]}/Bg_{i+1}.png"
    Cm_img_path = f"{folder_path}/{ls[5]}/Cg_{i+1}.png"
    img1 = cv2.imread(Tm_img_path)
    img2 = cv2.imread(Bm_img_path)
    img3 = cv2.imread(Cm_img_path)
    img = cv2.hconcat([img1, img2, img3])
    filename = f"{save_folder_path}/gradient_{i+1}.png"
    cv2.imwrite(filename, img)

img = []

ncols = 1
nrows = 10

for i in range(10):
    save_path = f"{save_folder_path}/s_c_pb_{i+1}.png"
    Sobel = f"{folder_path}/{ls[6]}/{i+1}.png"
    Canny = f"{folder_path}/{ls[7]}/{i+1}.png"
    PbLite = f"{folder_path}/{ls[8]}/Pblite_{i+1}.png"
    img1 = cv2.imread(Sobel)
    img2 = cv2.imread(Canny)
    img3 = cv2.imread(PbLite)

    img = (cv2.hconcat([img1, img2, img3]))
    cv2.imwrite(save_path, img)

# %%
img_path = "/Users/tvidk/Library/CloudStorage/OneDrive-WorcesterPolytechnicInstitute(wpi.edu)/WPI/Education/RBE 549/HW 0/YourDirectoryID_hw0/Phase1/BSDS500/Texton_Maps/TextonMap_1.png"
img = cv2.imread(img_path)
p = []
for i in img:
    for j in i:
        print(j)
# plt.imshow(img)
# plt.show()
# Out:
# [ 50 124 124]
# [62 56 56]
# [56 30 59]
# [62 65 63]
# [55 78 68]
# [72 75 40]
# [72 68 40]
# [54 63 13]
# [20 59 63]
# [59 54 65]
# [11 54 47]
# [62 59 63]
# [65 60 13]
# [96 86 53]
# [ 83 108 112]
# [68 48 67]
# [ 1 64 67]
# [ 72 111 102]
# [ 42  34 125]
# [63 86 31]
# [55 68 86]
# [56 63 96]
# [54 11 78]
# [30 55 72]
# [55 54 65]
# [20 54 22]
# [ 5 30  1]
# [65 65 13]
# [42 60 40]
# [ 1 75 15]
# [ 59  83 103]
# [62 85 32]
# [56 81 86]
# [54 75 15]
# [ 65  96 111]
# [ 42  83 105]
# [ 42  83 111]
# [63 83 34]
# [47 36 86]
# [55 25 13]
# [54 63 42]
# [54 22 22]
# [55 65 22]
# [56 59 65]
# [20 55 11]
# [20 54 11]
# [20 30 22]
# [ 5 56 22]
# [30 62 11]
# [ 5 56 54]
# [56 50 56]
# [ 5 56 56]
# [56 56  5]
# [20 56 55]
# [55 55 22]
# [47 72 42]
# [72 42 60]
# [65 63  1]
# [30 65 22]
# [62 59 47]
# [50 54 30]
# [50 56 56]
# [20 62 20]
# [62 62 20]
# [56 50 62]
# [56 62 30]
# [20 54 11]
# [62 11 11]
# [ 5 72 72]
# [47 25 78]
# [60 36 81]
# [25 85 86]
# [42 83 40]
# [ 5 72 42]
# [47 54 65]
# ...
